# %% [markdown]
# # SILVER Notebook Lookup Tables

# %% [markdown]
# ### Parameters

# %%
dbutils.widgets.text("sourcefolder","netflix_directors")
dbutils.widgets.text("targetfolder","netflix_directors")

# %% [markdown]
# ### Variables

# %%
var_src_folder = dbutils.widgets.get("sourcefolder")
var_tgt_folder = dbutils.widgets.get("targetfolder")

# %%
df = spark.read.format("csv")\
.option("header",True)\
.option("inferSchema",True)\
.load(f"abfss://bronze@projectdatalakestrgacc.dfs.core.windows.net/{var_src_folder}")

# %%
df.display()

# %%
df.write.format("delta")\
    .mode("append")\
    .option("path",f"abfss://silver@projectdatalakestrgacc.dfs.core.windows.net/{var_tgt_folder}")\
    .save()
